# %% [markdown]
# <a href="https://colab.research.google.com/github/Okalmary254/Okalmary254/blob/main/kazi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df1=pd.read_csv("/content/Automobile_data.csv")

#binning
bins=np.linspace(min(df1['horsepower']),max(df1['horsepower']),4)
bins
df1.head()
df1.to_csv('clean_df.csv')

# %% [markdown]
# correlation is a meausre of
# it meausres the linear dependence btwn two variables x and y, the resulting coefficient is a value btwn -1 and 1. 1 is a perfect +ve , 0 no relation, -1 is -ve relation.
# P-value is a relation btwn 2 variables is statistically significant, when it is 0.01, we say there's strong evidence of significant, 0.5 moderate significant and 0.05 weak significant. <1 no evident of relation.

# %%
import pandas as pd
import numpy as np

df1 = pd.read_csv("/content/Automobile_data.csv")

# Convert 'horsepower' column to numeric, handling non-numeric values
df1['horsepower'] = pd.to_numeric(df1['horsepower'], errors='coerce')

# Binning after conversion
bins = np.linspace(df1['horsepower'].min(), df1['horsepower'].max(), 4)
print(bins)
group_names=['low', 'medium', 'high']
df1['horsepower-binned'] = pd.cut(df1['horsepower'], bins, labels=group_names, include_lowest=True)
df1[['horsepower', 'horsepower-binned']].head(20)
horsepower_binned_count = df1['horsepower-binned'].value_counts()

print(horsepower_binned_count)

import matplotlib.pyplot as plt
pyplot.bar(group_names, horsepower_binned_count)
plt.xlabel("horsepower")
plt.ylabel("count")
plt.title("horsepower bins")
plt.show()
#creating dummy variable from fuel type and aspiration
dummy_variable_1 = pd.get_dummies(df1["fuel-type"])
dummy_variable_1
dummy_variable_1.rename(columns={'gas':'fuel-type-gas', 'diesel':'fuel-type-diesel'}, inplace=True)
dummy_variable_1.head()
df1 = pd.concat([df1, dummy_variable_1], axis=1)
df1.drop("fuel-type", axis = 1, inplace=True)
dummy_variable_2 = pd.get_dummies(df1["aspiration"])
dummy_variable_2
dummy_variable_2.rename(columns={'std':'aspiration-std', 'turbo':'aspiration-turbo'}, inplace=True)
dummy_variable_2.head()
df1 = pd.concat([df1, dummy_variable_2], axis=1)
df1
#saving the data
df1.to_csv('clean_automobile.csv')
df1.to_csv('clean_automobile.xls')
df3=pd.read_csv("/content/asclean_auto (1).csv")
df3.head()
#analyzing individual data pattern using visualization
#corelation
df3.corr()
df3.shape
#correlation for bore, stroke, horsepower and compression ratio
df3[['bore','stroke','compression-ratio','horsepower']].corr()

##categorical variables for body syle and price
sns.boxplot(x="body-style", y="price", data=df3)
#residual plot
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(df3['highway-mpg'], df3['price'])
plt.show()
# Out:
# [ 48. 128. 208. 288.]
# horsepower-binned
# low       161
# medium     40
# high        2
# Name: count, dtype: int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-6a48a7269127> in <cell line: 45>()
#      43 #analyzing individual data pattern using visualization
#      44 #corelation
# ---> 45 df3.corr()
#      46 df3.shape
#      47
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10052         cols = data.columns
#   10053         idx = cols.copy()
# > 10054         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10055
#   10056         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# ...

# %%
import pandas as pd
import numpy as np

df1 = pd.read_csv("/content/Automobile_data.csv")

# Convert 'horsepower' column to numeric, handling non-numeric values
df1['horsepower'] = pd.to_numeric(df1['horsepower'], errors='coerce')

# Binning after conversion
bins = np.linspace(df1['horsepower'].min(), df1['horsepower'].max(), 4)
print(bins)
group_names=['low', 'medium', 'high']
df1['horsepower-binned'] = pd.cut(df1['horsepower'], bins, labels=group_names, include_lowest=True)
df1[['horsepower', 'horsepower-binned']].head(20)
horsepower_binned_count = df1['horsepower-binned'].value_counts()

print(horsepower_binned_count)

import matplotlib.pyplot as plt
pyplot.bar(group_names, horsepower_binned_count)
plt.xlabel("horsepower")
plt.ylabel("count")
plt.title("horsepower bins")
plt.show()
#creating dummy variable from fuel type and aspiration
dummy_variable_1 = pd.get_dummies(df1["fuel-type"])
dummy_variable_1
dummy_variable_1.rename(columns={'gas':'fuel-type-gas', 'diesel':'fuel-type-diesel'}, inplace=True)
dummy_variable_1.head()
df1 = pd.concat([df1, dummy_variable_1], axis=1)
df1.drop("fuel-type", axis = 1, inplace=True)
dummy_variable_2 = pd.get_dummies(df1["aspiration"])
dummy_variable_2
dummy_variable_2.rename(columns={'std':'aspiration-std', 'turbo':'aspiration-turbo'}, inplace=True)
dummy_variable_2.head()
df1 = pd.concat([df1, dummy_variable_2], axis=1)
df1
#saving the data
df1.to_csv('clean_automobile.csv')
df1.to_csv('clean_automobile.xls')
df3=pd.read_csv("/content/asclean_auto (1).csv")

# Identify non-numeric columns in df3
non_numeric_cols = df3.select_dtypes(exclude=['number']).columns

# Attempt to convert non-numeric columns to numeric
for col in non_numeric_cols:
    df3[col] = pd.to_numeric(df3[col], errors='coerce')  # 'coerce' will replace non-convertible values with NaN

df3.head()
df3.corr()
df3.shape

#correlation for bore, stroke, horsepower and compression ratio
df3[['bore','stroke','compression-ratio','horsepower']].corr()
#linear correlation
import seaborn as sns
sns.regplot(x="engine-size", y="price", data=df3)
plt.ylim(0,)
#highway mpg
sns.regplot(x="highway-mpg", y="price", data=df3)
plt.ylim(0,)
#engine size and price
sns.regplot(x="engine-size", y="price", data=df3)
plt.ylim(0,)
#horsepower and price
sns.regplot(x="horsepower", y="price", data=df3)
plt.ylim(0,)
#peak rpm and price
sns.regplot(x="peak-rpm", y="price", data=df3)
plt.ylim(0,)

#descriptive
df3.describe()


#forming groups
df3['drive-wheels'].unique()
df3_group_one = df3[['drive-wheels','body-style','price']]
df3_group_one = df3_group_one.groupby(['drive-wheels','body-style'],as_index=False).mean()
##df3_group_one
df3_gptest= df3[['drive-wheels','body-style','price']]
grouped_test1=df3_gptest.groupby(['drive-wheels','body-style'],as_index=False).mean()
grouped_test1
grouped_pivot = grouped_test1.pivot(index='drive-wheels',columns='body-style')
grouped_pivot
fig, ax = plt.subplots()
im = ax.pcolor(grouped_pivot, cmap='RdBu')

#label names
row_labels = grouped_pivot.columns.levels[1]
col_labels = grouped_pivot.index

#move ticks and labels to the center
ax.set_xticks(np.arange(grouped_pivot.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(grouped_pivot.shape[0]) + 0.5, minor=False)

#insert labels
ax.set_xticklabels(row_labels, minor=False)
ax.set_yticklabels(col_labels, minor=False)

#rotate label if too long
plt.xticks(rotation=90)

fig.colorbar(im)
plt.show()

#pearson correlation
from scipy import stats
#pearson correlation for wheel base vs price
pearson_coef, p_value = stats.pearsonr(df3['wheel-base'], df3['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
#pearson correlation for horsepower vs price
pearson_coef, p_value = stats.pearsonr(df3['horsepower'], df3['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
#pearson correlation for length vs price
pearson_coef, p_value = stats.pearsonr(df3['length'], df3['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
#pearson correlation for width against price
pearson_coeff, p_value = stats.pearsonr(df3['width'], df3['price'])
print("The Pearson Correlation Coefficient is", pearson_coeff, " with a P-value of P =", p_value)
#cab-weight vs price
pearson_coeff, p_value = stats.pearsonr(df3['curb-weight'], df3['price'])
print("The Pearson Correlation Coefficient is", pearson_coeff, " with a P-value of P =", p_value)
#engine size vs price
pearson_coeff, p_value = stats.pearsonr(df3['engine-size'], df3['price'])
print("The Pearson Correlation Coefficient is", pearson_coeff, " with a P-value of P =", p_value)
#city-mpg vs price
pearson_coeff, p_value = stats.pearsonr(df3['city-mpg'], df3['price'])

#simple linear and multilinear regression
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm
X = df3[['highway-mpg']]
Y = df3['price']
lm.fit(X,Y)
Y=lm.predict(X)
Y[0:5]
print(lm.intercept_)
print(lm.coef_)
#multi linear
Z = df3[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]
lm.fit(Z, df3['price'])
lm.intercept_
lm.coef_
#prediction
Y_hat=lm.predict(Z)
Y[0:5]
Z.head()
#r-square
#print('The R-square is: ', lm.score(X,Y))
#mse
#from sklearn.metrics import mean_squared_error
#mse=mean_squared_error(df3['price'], Y)
#mse = mean_squared_error(df3['price'], Y_predict_multifit)
## r-square and fitting for multi regression
#lm.fit(Z, df3['price'])
#r_square = lm.score(Z, df3['price'])
#Y_predict_multifit = lm.predict(Z)
#print('The mean square error of price and predicted value using multifit is: ', mse)
#print('The MSE is: ', mean_squared_error(df3['price'], Y_predict_multifit))
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(df3['price'], Y)

# r-square and fitting for multi regression
lm.fit(Z, df3['price'])
r_square = lm.score(Z, df3['price'])
Y_predict_multifit = lm.predict(Z)  # Calculate Y_predict_multifit before using it

mse = mean_squared_error(df3['price'], Y_predict_multifit)  # Now you can use Y_predict_multifit
print('The mean square error of price and predicted value using multifit is: ', mse)
print('The MSE is: ', mean_squared_error(df3['price'], Y_predict_multifit))
# Out:
# [ 48. 128. 208. 288.]
# horsepower-binned
# low       161
# medium     40
# high        2
# Name: count, dtype: int64
# The Pearson Correlation Coefficient is 0.584641822265508  with a P-value of P = 8.076488270732885e-20
# The Pearson Correlation Coefficient is 0.8096068016571054  with a P-value of P = 6.273536270650351e-48
# The Pearson Correlation Coefficient is 0.6906283804483639  with a P-value of P = 8.01647746615924e-30
# The Pearson Correlation Coefficient is 0.7512653440522674  with a P-value of P = 9.20033551048144e-38
# The Pearson Correlation Coefficient is 0.8344145257702843  with a P-value of P = 2.189577238893965e-53
# The Pearson Correlation Coefficient is 0.8723351674455185  with a P-value of P = 9.265491622198793e-64
# 38423.3058581574
# [-821.73337832]
# The mean square error of price and predicted value using multifit is:  11979300.34981888
# The MSE is:  11979300.34981888
